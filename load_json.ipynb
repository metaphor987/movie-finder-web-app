# %%
import os
import json

# %%
dataset = []
if os.path.exists('./public/data/movies.json'):
  with open('./public/data/movies.json', 'r', encoding='utf-8') as fin:
    text = fin.read()
    if len(text) > 0:
      dataset = json.loads(text)

# %%
if os.path.exists('./public/data/movies.json'):
  with open('./public/data/movies.json', 'r', encoding='utf-8') as fin:
    json_object = json.load(fin)

# %%
type(json_object)
# Out:
# list

# %%
len(json_object)
# Out:
# 28795

# %%
a = []
a.append(1)

# %%
type(a)
# Out:
# list

# %%
games = []
for game in json_object:
    oneGame = json_object[game]
    games.append(oneGame)

# %%
type(games[0])
# Out:
# dict

# %%
final_json = json.dumps(games)
  
# Writing to sample.json
with open("sample.json", "w") as outfile:
    outfile.write(final_json)

# %%
type(dataset)
# Out:
# dict

# %%
for course in dataset:
    appID = course                             # AppID, unique identifier for each app (string).
    game = dataset[course]
    print(game['name'])
# Out:
# Again?
# goto
# Political Puzzle
# Bomb Riders
# The Navigator
# Bomber 95
# Globat Pixels
# Simple Racing
# Deep Space Classic
# Project Skylab
# InductVR (beta)
# GRITS Racing
# Phantom Thief Celianna
# One Piu Day
# 像素修真 - Pixel Xiuzhen
# GUNGRAVE VR U.N
# Galactis
# Gravia
# Defenders of Ekron - Definitive Edition
# Conception PLUS: Maidens of the Twelve Stars
# Bare Boob Brawlerz Visual Novel: Vol 1
# Gunkid 99
# Gumstein: The Awakening
# Seacurity Breach
# Zombie Flick | 僵尸快打
# Typical
# Voidship: The Long Journey
# Weaverse
# TITAN SLAYER Ⅱ
# Gaia
# Music Maker Steam Edition
# MONOWARS: Red Zone
# Skyland Defense
# Steel Crew
# TAL: Arctic 2
# NOCE
# Hentai Case Opening
# Observation
# Minotaur Arcade Volume 1
# Repeat the image: Animals
# Metal Brigade Tactics
# Kamikaze Cube 2
# Encore Card Games Collection
# Encore Casino Games Collection
# Combat Rush
# Under One Wing
# Rapid Racing
# LUXO Buddies
# Starkid's Obstacle Course
# The Asteroid Belt's Trial
# GALAXY TOP WING
# ...

# %%
type(dataset)
# Out:
# dict

# %%
num
# Out:
# 54946
